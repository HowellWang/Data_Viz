# %% [markdown]
# # Data Breaches (Preparing for visualization)
# # link (Lab 2): https://goo.gl/zUSQyZ
# # MSIS 2629 - Data Visualization
# # Lab 2
# # Submitted by: Yuhao Wang

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("./Information is Beautiful- Data Breaches (public).xlsx")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 10000)

# %%
df.head(5)
# Out:
#                       Entity  \
# 0                        NaN
# 1                        AOL
# 2  Automatic Data Processing
# 3            Ameritrade Inc.
# 4                  Citigroup
#
#                                                   alternative name  \
# 0                                                              NaN
# 1                                                  American Online
# 2                         Business outsourcing, payrolls, benefits
# 3  Computer backup tape containing personal information was lost.
# 4                                                              NaN
#
#                                                                                                                                                                                  story  \
# 0                                                                                                                      Elaboration if there's an interesting story or detail behind it
# ...

# %%
#df["METHOD OF LEAK"].unique()
df.groupby(by="METHOD OF LEAK").count()
# Out:
#                         Entity  alternative name  story  YEAR  records lost  \
# METHOD OF LEAK
# accidentally published      17                 4     15    17            17
# hacked                     155                78    131   155           153
# hacked                       1                 0      1     1             1
# inside job                  19                12     16    19            19
# lost / stolen device        49                20     44    49            49
# poor security               12                 4     10    12            12
#
#                         ORGANISATION  interesting story  NO OF RECORDS STOLEN  \
# METHOD OF LEAK
# accidentally published            17                  6                    17
# hacked                           155                 33                   155
# hacked                             1                  0                     1
# inside job                        19                  4                    19
# ...

# %%
df.groupby(by="ORGANISATION").count()
# Out:
#                         Entity  alternative name  story  YEAR  records lost  \
# ORGANISATION
# academic                     9                 3      4     9             9
# app                          2                 1      2     2             2
# energy                       3                 1      3     3             3
# financial                   31                19     25    31            31
# gaming                       7                 4      6     7             6
# government                  37                10     33    37            37
# government, healthcare       2                 1      2     2             2
# government, military         1                 0      1     1             1
# healthcare                  36                18     33    36            36
# legal                        1                 1      1     1             1
# media                        3                 1      3     3             3
# ...

# %%
df.groupby(by="YEAR").count()
# Out:
#                                                                                                 Entity  \
# YEAR
# 0                                                                                                    1
# 1                                                                                                    4
# 2                                                                                                    6
# 3                                                                                                   13
# 4                                                                                                   16
# 5                                                                                                   14
# 6                                                                                                   20
# 7                                                                                                   35
# ...

# %%
df.groupby(by="records lost").count()
# Out:
#                                                         Entity  \
# records lost
# 1025                                                         1
# 30000                                                        1
# 34000                                                        2
# 35000                                                        1
# 40000                                                        1
# 43000                                                        1
# 50000                                                        2
# 50500                                                        1
# 52000                                                        1
# 62000                                                        1
# 72000                                                        2
# 73000                                                        1
# 76000                                                        1
# 84000                                                        1
# ...

# %%
df1 = df[1:]

# %%
df1.YEAR += 2004
df1["YEAR"][df1.YEAR == 2018] = 2017

# %%
df1.head()
# Out:
#                         Entity  \
# 1                          AOL
# 2    Automatic Data Processing
# 3              Ameritrade Inc.
# 4                    Citigroup
# 5  Cardsystems Solutions Inc.
#
#                                                           alternative name  \
# 1                                                          American Online
# 2                                 Business outsourcing, payrolls, benefits
# 3          Computer backup tape containing personal information was lost.
# 4                                                                      NaN
# 5  Third-party payment processor for Visa, Mastercard, Amex,  and Discover
#
# ...

# %%
df1["DATA SENSITIVITY"][2]

for i in range(1, len(df1["DATA SENSITIVITY"]) + 1):
    if df1["DATA SENSITIVITY"][i] == 1:
        df1["DATA SENSITIVITY"][i] = "Just email address/Online information"
    elif df1["DATA SENSITIVITY"][i] == 20:
        df1["DATA SENSITIVITY"][i] = "SSN/Personal details"
    elif df1["DATA SENSITIVITY"][i] == 300:
        df1["DATA SENSITIVITY"][i] = "Credit card information"
    elif df1["DATA SENSITIVITY"][i] == 4000:
        df1["DATA SENSITIVITY"][i] = "Email password/Health records"
    else:
        df1["DATA SENSITIVITY"][i] = "Full bank account details"
df1["DATA SENSITIVITY"]
# Out:
# 1      Just email address/Online information
# 2                       SSN/Personal details
# 3                       SSN/Personal details
# 4                    Credit card information
# 5                    Credit card information
# 6                       SSN/Personal details
# 7                    Credit card information
# 8      Just email address/Online information
# 9      Just email address/Online information
# 10     Just email address/Online information
# 11                      SSN/Personal details
# 12                      SSN/Personal details
# 13                      SSN/Personal details
# 14                      SSN/Personal details
# 15                   Credit card information
# 16                      SSN/Personal details
# 17                      SSN/Personal details
# 18                      SSN/Personal details
# 19                   Credit card information
# 20     Just email address/Online information
# 21                   Credit card information
# ...

# %%
df1.head()
# Out:
#                         Entity  \
# 1                          AOL
# 2    Automatic Data Processing
# 3              Ameritrade Inc.
# 4                    Citigroup
# 5  Cardsystems Solutions Inc.
#
#                                                           alternative name  \
# 1                                                          American Online
# 2                                 Business outsourcing, payrolls, benefits
# 3          Computer backup tape containing personal information was lost.
# 4                                                                      NaN
# 5  Third-party payment processor for Visa, Mastercard, Amex,  and Discover
#
# ...

# %%
df1 = df1.ix[:,0:10]

# %%
columns = ['Entity', 'YEAR', 'records lost', 'ORGANISATION', 'METHOD OF LEAK',  'DATA SENSITIVITY']
df2 = pd.DataFrame(df1, columns=columns)

# %%
df2.dropna(inplace=True)
df2
# Out:
#                                              Entity  YEAR records lost  \
# 1                                               AOL  2004     92000000
# 2                         Automatic Data Processing  2005       125000
# 3                                   Ameritrade Inc.  2005       200000
# 4                                         Citigroup  2005      3900000
# 5                       Cardsystems Solutions Inc.   2005     40000000
# 6                                   Hewlett Packard  2006       200000
# 7                        Countrywide Financial Corp  2006      2600000
# 8                                              KDDI  2006      4000000
# 9                        T-Mobile, Deutsche Telecom  2006     17000000
# 10                                              AOL  2006     20000000
# 11                           US Dept of Vet Affairs  2006     26500000
# 12                                    Texas Lottery  2007        89000
# ...

# %%
df2.to_csv("test.csv",encoding="utf-8", index=False)
